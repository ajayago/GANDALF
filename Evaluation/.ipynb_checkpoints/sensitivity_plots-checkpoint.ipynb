# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib
matplotlib.rcParams.update({'font.size': 14})
import matplotlib.pyplot as plt

# %%
import os
import pickle

# %%
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
from scipy.stats import pearsonr, spearmanr

# %%
criteria = "ut_0_7" # ut_0_7 or lt_0_1
file_path = f"/data/ajayago/papers_data/DiffDRP_v7/run_files/saved_model_annotated_mutations/"

# %%
# experiment 1A settings
with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment1/SettingA/patients_fold0_processed.pkl", "rb") as f:
    exp1A_patient_fold0 = pickle.load(f)

with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment1/SettingA/patients_fold1_processed.pkl", "rb") as f:
    exp1A_patient_fold1 = pickle.load(f)

with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment1/SettingA/patients_fold2_processed.pkl", "rb") as f:
    exp1A_patient_fold2 = pickle.load(f)

# %%
with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment2/SettingA/patients_fold0_processed.pkl", "rb") as f:
    exp2A_fold0 = pickle.load(f)

with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment2/SettingA/patients_fold1_processed.pkl", "rb") as f:
    exp2A_fold1 = pickle.load(f)

with open("/data/ajayago/papers_data/systematic_assessment/input_types/annotated_mutations/Experiment2/SettingA/patients_fold2_processed.pkl", "rb") as f:
    exp2A_fold2 = pickle.load(f)

# %%
combined_df_fold0_subset = pd.DataFrame()
for d in ['FLUOROURACIL', 'GEMCITABINE', 'PACLITAXEL', 'TEMOZOLOMIDE', 'CISPLATIN']:
    print(exp1A_patient_fold0["test"][d].shape)
    combined_df_fold0_subset = pd.concat([combined_df_fold0_subset, exp1A_patient_fold0["test"][d][["sample_id", "drug_name", "recist"]]], ignore_index=True)
# Out:
# (12, 7781)
# (14, 7781)
# (8, 7781)
# (30, 7781)
# (27, 7781)

# %%
combined_df_fold1_subset = pd.DataFrame()
for d in ['FLUOROURACIL', 'GEMCITABINE', 'PACLITAXEL', 'TEMOZOLOMIDE', 'CISPLATIN']:
    print(exp1A_patient_fold1["test"][d].shape)
    combined_df_fold1_subset = pd.concat([combined_df_fold1_subset, exp1A_patient_fold1["test"][d][["sample_id", "drug_name", "recist"]]], ignore_index=True)
# Out:
# (11, 7781)
# (11, 7781)
# (10, 7781)
# (30, 7781)
# (30, 7781)

# %%
combined_df_fold2_subset = pd.DataFrame()
for d in ['FLUOROURACIL', 'GEMCITABINE', 'PACLITAXEL', 'TEMOZOLOMIDE', 'CISPLATIN']:
    print(exp1A_patient_fold2["test"][d].shape)
    combined_df_fold2_subset = pd.concat([combined_df_fold2_subset, exp1A_patient_fold2["test"][d][["sample_id", "drug_name", "recist"]]], ignore_index=True)
# Out:
# (11, 7781)
# (15, 7781)
# (8, 7781)
# (28, 7781)
# (28, 7781)

# %%
os.listdir(file_path)
# Out:
# ['DRP_model_val_corr_2A_ALL_fold1.pth',
#  'prediction_cell_lines_val_corr_2A_ALL_fold2.csv',
#  'prediction_patients_val_corr_2A_ALL_fold1_tuned4CISPLATIN.csv',
#  'prediction_patients_val_corr_2A_ALL_fold2_tuned4PACLITAXEL.csv',
#  'prediction_patients_val_corr_2A_ALL_fold0_tuned4FLUOROURACIL.csv',
#  'sensitivity_lt0_4_ut_0_7',
#  'best_val_corr_2A_ALL_fold0_cool-sweep-14.pkl',
#  'prediction_patients_val_corr_2A_ALL_fold2_tuned4FLUOROURACIL.csv',
#  'BaselineNN_1_val_corr_2A_ALL_fold0.pth',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold2_cell_line.pth',
#  'DRP_model_val_corr_2A_ALL_fold1_tuned4GEMCITABINE.pth',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold1_patient.pth',
#  'working_fold0',
#  'DRP_model_val_corr_2A_ALL_fold2_tuned4GEMCITABINE.pth',
#  'prediction_patients_val_corr_2A_ALL_fold2_tuned4GEMCITABINE.csv',
#  'prediction_patients_val_corr_2A_ALL_fold2_tuned4TEMOZOLOMIDE.csv',
#  'best_val_corr_2A_ALL_fold0_generous-sweep-4.pkl',
#  'best_pretrained_validation_loss_val_corr_2A_ALL_fold1.pth',
#  'DRP_model_val_corr_2A_ALL_fold2_tuned4TEMOZOLOMIDE.pth',
#  'MTL_model_fold1.pth',
#  'best_val_corr_2A_ALL_fold0_easy-sweep-3.pkl',
#  'BaselineNN_2_val_corr_2A_ALL_fold2.pth',
#  'DRP_model_val_corr_2A_ALL_fold2_tuned4FLUOROURACIL.pth',
#  'BaselineNN_1_val_corr_2A_ALL_fold2.pth',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold2_patient.pth',
#  'working_pseudolabeling_per_drug',
#  'best_val_corr_2A_ALL_fold0_easy-sweep-13.pkl',
#  'best_pretrained_validation_loss_val_corr_2A_ALL_fold0.pth',
#  'prediction_patients_val_corr_2A_ALL_fold1_tuned4PACLITAXEL.csv',
#  'pseudolabels_df_val_corr_2A_ALL_fold0.csv',
#  'prediction_patients_val_corr_2A_ALL_fold0_tuned4GEMCITABINE.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold0_tuned4TEMOZOLOMIDE.csv',
#  'sensitivity_lt0_1_ut_0_7',
#  'best_val_corr_2A_ALL_fold0_misty-sweep-7.pkl',
#  'sensitivity_lt0_1_ut_0_6',
#  'best_val_corr_2A_ALL_fold0_dry-sweep-10.pkl',
#  'augmented_cl_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold2.csv',
#  'prediction_patients_val_corr_2A_ALL_fold1.csv',
#  'sensitivity_lt0_1_ut_0_8',
#  'MTL_model_fold2.pth',
#  'DRP_model_val_corr_2A_ALL_fold1_tuned4FLUOROURACIL.pth',
#  'augmented_cl_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold0.csv',
#  'pseudolabels_df_val_corr_2A_ALL_fold1.csv',
#  'prediction_patients_val_corr_2A_ALL_fold1_tuned4TEMOZOLOMIDE.csv',
#  'sensitivity_lt0_2_ut_0_7',
#  'augmented_cl_test_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold2.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold2_tuned4FLUOROURACIL.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold1_tuned4CISPLATIN.csv',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold0_patient.pth',
#  'augmented_cl_test_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold1.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold2_tuned4CISPLATIN.csv',
#  'best_val_corr_2A_ALL_fold0_faithful-sweep-2.pkl',
#  'BaselineNN_1_val_corr_2A_ALL_fold1.pth',
#  'prediction_patients_val_corr_2A_ALL_fold0_tuned4PACLITAXEL.csv',
#  'pseudolabels_df_val_corr_2A_ALL_fold2.csv',
#  'best_val_corr_2A_ALL_fold0_sweet-sweep-6.pkl',
#  'DRP_model_val_corr_2A_ALL_fold0_tuned4PACLITAXEL.pth',
#  'best_val_corr_2A_ALL_fold0_rosy-sweep-11.pkl',
#  'DRP_model_val_corr_2A_ALL_fold0_TEMOZOLOMIDE.pth',
#  'DRP_model_val_corr_2A_ALL_fold0_CISPLATIN.pth',
#  'BaselineNN_0_val_corr_2A_ALL_fold1.pth',
#  'sensitivity_lt0_1_ut_0_5',
#  'DRP_model_val_corr_2A_ALL_fold0_FLUOROURACIL.pth',
#  'prediction_patients_val_corr_2A_ALL_fold0.csv',
#  'DRP_model_val_corr_2A_ALL_fold0_tuned4FLUOROURACIL.pth',
#  'DRP_model_val_corr_2A_ALL_fold2_tuned4PACLITAXEL.pth',
#  'BaselineNN_2_val_corr_2A_ALL_fold1.pth',
#  'DRP_model_val_corr_2A_ALL_fold2.pth',
#  'prediction_patients_val_corr_2A_ALL_fold2_tuned4CISPLATIN.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold1.csv',
#  'best_val_corr_2A_ALL_fold0_resilient-sweep-1.pkl',
#  'best_val_corr_2A_ALL_fold0_peachy-sweep-9.pkl',
#  'best_val_corr_2A_ALL_fold0_volcanic-sweep-15.pkl',
#  'prediction_patients_val_corr_2A_ALL_fold2.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold1_tuned4FLUOROURACIL.csv',
#  'best_val_corr_2A_ALL_fold0_exalted-sweep-12.pkl',
#  'DRP_model_val_corr_2A_ALL_fold1_tuned4PACLITAXEL.pth',
#  'DRP_model_val_corr_2A_ALL_fold2_TEMOZOLOMIDE.pth',
#  'augmented_cl_test_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold0.csv',
#  'augmented_cl_clconditioned_uda_v2_vaeinput_val_corr_2A_ALL_fold1.csv',
#  'prediction_patients_val_corr_2A_ALL_fold0_tuned4TEMOZOLOMIDE.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold0_tuned4CISPLATIN.csv',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold1_cell_line.pth',
#  'working_fold2',
#  'prediction_cell_lines_val_corr_2A_ALL_fold0_tuned4FLUOROURACIL.csv',
#  'best_val_corr_2A_ALL_fold0_rosy-sweep-5.pkl',
#  'best_pretrained_vae_validation_loss_val_corr_2A_ALL_fold0_cell_line.pth',
#  'working_fold1',
#  'best_pretrained_validation_loss_val_corr_2A_ALL_fold2.pth',
#  'ablation_6Sep',
#  'DRP_model_val_corr_2A_ALL_fold1_tuned4CISPLATIN.pth',
#  'DRP_model_val_corr_2A_ALL_fold1_tuned4TEMOZOLOMIDE.pth',
#  'DRP_model_val_corr_2A_ALL_fold0_tuned4GEMCITABINE.pth',
#  'BaselineNN_0_val_corr_2A_ALL_fold0.pth',
#  'prediction_cell_lines_val_corr_2A_ALL_fold2_tuned4TEMOZOLOMIDE.csv',
#  'DRP_model_val_corr_2A_ALL_fold2_tuned4CISPLATIN.pth',
#  'sensitivity_lt0_3_ut_0_7',
#  'DRP_model_val_corr_2A_ALL_fold0.pth',
#  'DRP_model_val_corr_2A_ALL_fold1_TEMOZOLOMIDE.pth',
#  'prediction_patients_val_corr_2A_ALL_fold1_tuned4GEMCITABINE.csv',
#  'prediction_cell_lines_val_corr_2A_ALL_fold0.csv',
#  'DRP_model_val_corr_2A_ALL_fold0_auc.pth',
#  'BaselineNN_2_val_corr_2A_ALL_fold0.pth',
#  'prediction_cell_lines_val_corr_2A_ALL_fold1_tuned4TEMOZOLOMIDE.csv',
#  'best_val_corr_2A_ALL_fold0_fragrant-sweep-8.pkl',
#  'DRP_model_val_corr_2A_ALL_fold0_tuned4CISPLATIN.pth',
#  'ablation',
#  'DRP_model_val_corr_2A_ALL_fold1_FLUOROURACIL.pth',
#  'prediction_patients_val_corr_2A_ALL_fold0_tuned4CISPLATIN.csv',
#  'prediction_patients_val_corr_2A_ALL_fold1_tuned4FLUOROURACIL.csv',
#  'DRP_model_val_corr_2A_ALL_fold0_tuned4TEMOZOLOMIDE.pth',
#  'BaselineNN_0_val_corr_2A_ALL_fold2.pth',
#  'sensitivity_lt0_1_ut_0_9',
#  'DRP_model_val_corr_2A_ALL_fold0_PACLITAXEL.pth',
#  'DRP_model_val_corr_2A_ALL_fold2_FLUOROURACIL.pth']

# %%
fold = 0
res_df0 = pd.DataFrame()
for f in os.listdir(file_path):
    if criteria in f:
        path = f"{file_path}/{f}/prediction_patients_val_corr_2A_ALL_fold{fold}.csv"
        df = pd.read_csv(path, index_col=0)
        combined_df = pd.concat([exp2A_fold0["test"][["sample_id", "drug_name", "recist", "mappedProject", "dataset_name"]],df], axis=1)
        # fold_df = pd.merge(combined_df, combined_df_fold0_subset, on=["sample_id", "drug_name"])
        # print(fold_df.shape)
        auroc_val = round(roc_auc_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        auprc_val = round(average_precision_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        pearsonr_val = pearsonr(combined_df["y_true"], combined_df["y_pred"])
        thresh = f.split(f"_{criteria}")
        if "ut" in criteria:
            thresh_val = thresh[0].split("_")[-1]
        elif "lt" in criteria:
            thresh_val = thresh[1].split("_")[-1]
        res_dict = {"AUROC": auroc_val, "AUPRC": auprc_val, "pearsonr": pearsonr_val.statistic, "pearsonr_pval": pearsonr_val.pvalue, "threshold": f"0.{thresh_val}", "fold": fold}
        res_df0 = res_df0._append(res_dict, ignore_index=True)

res_df0
# Out:
#     AUROC   AUPRC  pearsonr  pearsonr_pval threshold  fold
# 0  0.8464  0.7330  0.492967   2.182372e-08       0.4     0
# 1  0.8041  0.7585  0.535586   6.938969e-10       0.1     0
# 2  0.8507  0.7616  0.595256   2.284066e-12       0.2     0
# 3  0.8361  0.6815  0.577779   1.374250e-11       0.3     0

# %%
fold = 1
res_df1 = pd.DataFrame()
for f in os.listdir(file_path):
    if criteria in f:
        path = f"{file_path}/{f}/prediction_patients_val_corr_2A_ALL_fold{fold}.csv"
        df = pd.read_csv(path, index_col=0)
        combined_df = pd.concat([exp2A_fold1["test"][["sample_id", "drug_name", "recist", "mappedProject", "dataset_name"]],df], axis=1)
        # fold_df = pd.merge(combined_df, combined_df_fold0_subset, on=["sample_id", "drug_name"])
        # print(fold_df.shape)
        auroc_val = round(roc_auc_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        auprc_val = round(average_precision_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        pearsonr_val = pearsonr(combined_df["y_true"], combined_df["y_pred"])
        thresh = f.split(f"_{criteria}")
        if "ut" in criteria:
            thresh_val = thresh[0].split("_")[-1]
        elif "lt" in criteria:
            thresh_val = thresh[1].split("_")[-1]
        res_dict = {"AUROC": auroc_val, "AUPRC": auprc_val, "pearsonr": pearsonr_val.statistic, "pearsonr_pval": pearsonr_val.pvalue, "threshold": f"0.{thresh_val}", "fold": fold}
        # res_dict = {"AUROC": auroc_val, "AUPRC": auprc_val, "pearsonr": pearsonr_val.statistic, "pearsonr_pval": pearsonr_val.pvalue, "threshold": f"{f.split('_')[-2]}.{f.split('_')[-1]}", "fold": fold}
        res_df1 = res_df1._append(res_dict, ignore_index=True)

res_df1
# Out:
#     AUROC   AUPRC  pearsonr  pearsonr_pval threshold  fold
# 0  0.8589  0.7892  0.669400   3.894641e-16       0.4     1
# 1  0.8892  0.8069  0.688215   2.669143e-17       0.1     1
# 2  0.8627  0.7509  0.652916   3.490435e-15       0.2     1
# 3  0.8605  0.7641  0.664247   7.845758e-16       0.3     1

# %%
fold = 2
res_df2 = pd.DataFrame()
for f in os.listdir(file_path):
    if criteria in f:
        path = f"{file_path}/{f}/prediction_patients_val_corr_2A_ALL_fold{fold}.csv"
        df = pd.read_csv(path, index_col=0)
        combined_df = pd.concat([exp2A_fold2["test"][["sample_id", "drug_name", "recist", "mappedProject", "dataset_name"]],df], axis=1)
        # fold_df = pd.merge(combined_df, combined_df_fold0_subset, on=["sample_id", "drug_name"])
        # print(fold_df.shape)
        auroc_val = round(roc_auc_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        auprc_val = round(average_precision_score(combined_df["y_true"], combined_df["y_pred"]), 4)
        pearsonr_val = pearsonr(combined_df["y_true"], combined_df["y_pred"])
        thresh = f.split(f"_{criteria}")
        if "ut" in criteria:
            thresh_val = thresh[0].split("_")[-1]
        elif "lt" in criteria:
            thresh_val = thresh[1].split("_")[-1]
        res_dict = {"AUROC": auroc_val, "AUPRC": auprc_val, "pearsonr": pearsonr_val.statistic, "pearsonr_pval": pearsonr_val.pvalue, "threshold": f"0.{thresh_val}", "fold": fold}
        # res_dict = {"AUROC": auroc_val, "AUPRC": auprc_val, "pearsonr": pearsonr_val.statistic, "pearsonr_pval": pearsonr_val.pvalue, "threshold": f"{f.split('_')[-2]}.{f.split('_')[-1]}", "fold": fold}
        res_df2 = res_df2._append(res_dict, ignore_index=True)

res_df2
# Out:
#     AUROC   AUPRC  pearsonr  pearsonr_pval threshold  fold
# 0  0.8186  0.7355  0.559595   1.170383e-10       0.4     2
# 1  0.8294  0.7686  0.605509   1.206041e-12       0.1     2
# 2  0.8221  0.7513  0.590890   5.598014e-12       0.2     2
# 3  0.8275  0.7597  0.581950   1.379015e-11       0.3     2

# %%
all_folds_df = pd.concat([res_df0, res_df1, res_df2])
all_folds_df
# Out:
#     AUROC   AUPRC  pearsonr  pearsonr_pval threshold  fold
# 0  0.8464  0.7330  0.492967   2.182372e-08       0.4     0
# 1  0.8041  0.7585  0.535586   6.938969e-10       0.1     0
# 2  0.8507  0.7616  0.595256   2.284066e-12       0.2     0
# 3  0.8361  0.6815  0.577779   1.374250e-11       0.3     0
# 0  0.8589  0.7892  0.669400   3.894641e-16       0.4     1
# 1  0.8892  0.8069  0.688215   2.669143e-17       0.1     1
# 2  0.8627  0.7509  0.652916   3.490435e-15       0.2     1
# 3  0.8605  0.7641  0.664247   7.845758e-16       0.3     1
# 0  0.8186  0.7355  0.559595   1.170383e-10       0.4     2
# 1  0.8294  0.7686  0.605509   1.206041e-12       0.1     2
# 2  0.8221  0.7513  0.590890   5.598014e-12       0.2     2
# 3  0.8275  0.7597  0.581950   1.379015e-11       0.3     2

# %%
all_folds_df.groupby(["threshold"]).agg("mean")
# Out:
#               AUROC     AUPRC  pearsonr  pearsonr_pval  fold
# threshold
# 0.1        0.840900  0.778000  0.609770   2.317010e-10   1.0
# 0.2        0.845167  0.754600  0.613021   2.628523e-12   1.0
# 0.3        0.841367  0.735100  0.607992   9.177813e-12   1.0
# 0.4        0.841300  0.752567  0.573987   7.313585e-09   1.0

# %%
all_folds_df_plt = pd.melt(all_folds_df, id_vars="threshold", value_vars=["AUROC", "AUPRC"], value_name="metric").rename(columns={"metric": "value", "variable": "metric"})
all_folds_df_plt
# Out:
#    threshold metric   value
# 0        0.4  AUROC  0.8464
# 1        0.1  AUROC  0.8041
# 2        0.2  AUROC  0.8507
# 3        0.3  AUROC  0.8361
# 4        0.4  AUROC  0.8589
# 5        0.1  AUROC  0.8892
# 6        0.2  AUROC  0.8627
# 7        0.3  AUROC  0.8605
# 8        0.4  AUROC  0.8186
# 9        0.1  AUROC  0.8294
# 10       0.2  AUROC  0.8221
# 11       0.3  AUROC  0.8275
# 12       0.4  AUPRC  0.7330
# 13       0.1  AUPRC  0.7585
# 14       0.2  AUPRC  0.7616
# 15       0.3  AUPRC  0.6815
# 16       0.4  AUPRC  0.7892
# 17       0.1  AUPRC  0.8069
# 18       0.2  AUPRC  0.7509
# 19       0.3  AUPRC  0.7641
# 20       0.4  AUPRC  0.7355
# 21       0.1  AUPRC  0.7686
# 22       0.2  AUPRC  0.7513
# 23       0.3  AUPRC  0.7597

# %%
# Converting above to point plot
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.pointplot(
    data=all_folds_df_plt.sort_values(by="threshold"), x="threshold", y="value", hue="metric", errorbar=("ci", 95),ax=ax, markers="o", palette={"AUROC": "blueviolet", "AUPRC": "purple"}
)

plt.legend(bbox_to_anchor=(1.13, 1))
if "ut" in criteria:
    plt.xlabel("Pseudo label lower threshold")
elif "lt" in criteria:
    plt.xlabel("Pseudo label upper threshold")
# plt.xlim(-0.1, 2.1)
